# %%
import pandas as pd

# %%
df = pd.read_csv('../data/evals.csv')

# %%
df.head(3)
# Out:
#    score          rank ethnicity  gender language  age  cls_perc_eval  \
# 0    4.7  tenure track  minority  female  english   36       55.81395
# 1    4.1  tenure track  minority  female  english   36       68.80000
# 2    3.9  tenure track  minority  female  english   36       60.80000
#
#    cls_did_eval  cls_students cls_level  ...   cls_credits bty_f1lower  \
# 0            24            43     upper  ...  multi credit           5
# 1            86           125     upper  ...  multi credit           5
# 2            76           125     upper  ...  multi credit           5
#
#    bty_f1upper  bty_f2upper  bty_m1lower  bty_m1upper  bty_m2upper  bty_avg  \
# 0            7            6            2            4            6      5.0
# 1            7            6            2            4            6      5.0
# 2            7            6            2            4            6      5.0
#
#    pic_outfit pic_color
# 0  not formal     color
# 1  not formal     color
# ...

# %%
df.shape
# Out:
# (463, 21)

# %%
df[:3]
# Out:
#    score          rank ethnicity  gender language  age  cls_perc_eval  \
# 0    4.7  tenure track  minority  female  english   36       55.81395
# 1    4.1  tenure track  minority  female  english   36       68.80000
# 2    3.9  tenure track  minority  female  english   36       60.80000
#
#    cls_did_eval  cls_students cls_level  ...   cls_credits bty_f1lower  \
# 0            24            43     upper  ...  multi credit           5
# 1            86           125     upper  ...  multi credit           5
# 2            76           125     upper  ...  multi credit           5
#
#    bty_f1upper  bty_f2upper  bty_m1lower  bty_m1upper  bty_m2upper  bty_avg  \
# 0            7            6            2            4            6      5.0
# 1            7            6            2            4            6      5.0
# 2            7            6            2            4            6      5.0
#
#    pic_outfit pic_color
# 0  not formal     color
# 1  not formal     color
# ...

# %%
df['score'][1:5]
# Out:
# 1    4.1
# 2    3.9
# 3    4.8
# 4    4.6
# Name: score, dtype: float64

# %%
df[ ['score', 'rank'] ].head()
# Out:
#    score          rank
# 0    4.7  tenure track
# 1    4.1  tenure track
# 2    3.9  tenure track
# 3    4.8  tenure track
# 4    4.6       tenured

# %%
df.columns
# Out:
# Index(['score', 'rank', 'ethnicity', 'gender', 'language', 'age',
#        'cls_perc_eval', 'cls_did_eval', 'cls_students', 'cls_level',
#        'cls_profs', 'cls_credits', 'bty_f1lower', 'bty_f1upper', 'bty_f2upper',
#        'bty_m1lower', 'bty_m1upper', 'bty_m2upper', 'bty_avg', 'pic_outfit',
#        'pic_color'],
#       dtype='object')

# %%
df.columns[0]
# Out:
# 'score'

# %%
len(df.columns)
# Out:
# 21

# %%
['col'+str(i) for i in range(1, len(df.columns)+1)]

# %%
df.columns = ['col'+str(i) for i in range(1, len(df.columns)+1)]

# %%
df.dtypes
# Out:
# score            float64
# rank              object
# ethnicity         object
# gender            object
# language          object
# age                int64
# cls_perc_eval    float64
# cls_did_eval       int64
# cls_students       int64
# cls_level         object
# cls_profs         object
# cls_credits       object
# bty_f1lower        int64
# bty_f1upper        int64
# bty_f2upper        int64
# bty_m1lower        int64
# bty_m1upper        int64
# bty_m2upper        int64
# bty_avg          float64
# pic_outfit        object
# pic_color         object
# dtype: object

# %%
df.describe()
# Out:
#             score         age  cls_perc_eval  cls_did_eval  cls_students  \
# count  463.000000  463.000000     463.000000    463.000000    463.000000
# mean     4.174730   48.365011      74.427788     36.624190     55.177106
# std      0.543865    9.802742      16.756311     45.018481     75.072800
# min      2.300000   29.000000      10.416670      5.000000      8.000000
# 25%      3.800000   42.000000      62.696165     15.000000     19.000000
# 50%      4.300000   48.000000      76.923080     23.000000     29.000000
# 75%      4.600000   57.000000      87.249170     40.000000     60.000000
# max      5.000000   73.000000     100.000000    380.000000    581.000000
#
#        bty_f1lower  bty_f1upper  bty_f2upper  bty_m1lower  bty_m1upper  \
# count   463.000000   463.000000   463.000000   463.000000   463.000000
# mean      3.963283     5.019438     5.213823     3.412527     4.146868
# std       1.873936     1.934437     2.018224     1.637102     2.110586
# ...

# %%
df['score'].describe()
# Out:
# count    463.000000
# mean       4.174730
# std        0.543865
# min        2.300000
# 25%        3.800000
# 50%        4.300000
# 75%        4.600000
# max        5.000000
# Name: score, dtype: float64

# %%
df['rank'].describe()
# Out:
# count         463
# unique          3
# top       tenured
# freq          253
# Name: rank, dtype: object

# %%
score = df['score']
score
# Out:
# 0      4.7
# 1      4.1
# 2      3.9
# 3      4.8
# 4      4.6
#       ...
# 458    4.5
# 459    3.5
# 460    4.4
# 461    4.4
# 462    4.1
# Name: score, Length: 463, dtype: float64

# %%
type(score)
# Out:
# pandas.core.series.Series

# %%
score > 4.1
# Out:
# 0       True
# 1      False
# 2      False
# 3       True
# 4       True
#        ...
# 458     True
# 459    False
# 460     True
# 461     True
# 462    False
# Name: score, Length: 463, dtype: bool

# %%
len(score[ score < 3.5 ])
# Out:
# 48

# %%
df['score'].hist()

# %%
df['score'].plot()

# %%
df['score'] > 4.1
# Out:
# 0       True
# 1      False
# 2      False
# 3       True
# 4       True
#        ...
# 458     True
# 459    False
# 460     True
# 461     True
# 462    False
# Name: score, Length: 463, dtype: bool

# %%
df[ df['score'] > 4.1 ]
# Out:
#      score          rank     ethnicity  gender     language  age  \
# 0      4.7  tenure track      minority  female      english   36
# 3      4.8  tenure track      minority  female      english   36
# 4      4.6       tenured  not minority    male      english   59
# 5      4.3       tenured  not minority    male      english   59
# 9      4.5       tenured  not minority  female      english   40
# ..     ...           ...           ...     ...          ...  ...
# 455    4.5  tenure track  not minority    male      english   32
# 456    4.6  tenure track  not minority    male      english   32
# 458    4.5  tenure track  not minority    male      english   32
# 460    4.4  tenure track      minority  female  non-english   42
# 461    4.4  tenure track      minority  female  non-english   42
#
#      cls_perc_eval  cls_did_eval  cls_students cls_level  ...   cls_credits  \
# 0         55.81395            24            43     upper  ...  multi credit
# ...

# %%
df['ten_point_score'] = df['score'] * 2

# %%
df.tail()
# Out:
#      score          rank     ethnicity  gender     language  age  \
# 458    4.5  tenure track  not minority    male      english   32
# 459    3.5  tenure track      minority  female  non-english   42
# 460    4.4  tenure track      minority  female  non-english   42
# 461    4.4  tenure track      minority  female  non-english   42
# 462    4.1  tenure track      minority  female  non-english   42
#
#      cls_perc_eval  cls_did_eval  cls_students cls_level  ... bty_f1upper  \
# 458       60.46511            52            86     upper  ...           6
# 459       57.14286            48            84     upper  ...           8
# 460       77.61194            52            67     upper  ...           8
# 461       81.81818            54            66     upper  ...           8
# 462       80.00000            28            35     lower  ...           8
#
#     bty_f2upper  bty_m1lower  bty_m1upper  bty_m2upper  bty_avg  pic_outfit  \
# ...

# %%
df['number'] = [i for i in range(1, len(df)+1)]
